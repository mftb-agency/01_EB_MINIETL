# %% [markdown]
# PROYECTO MINI ETL

# %%
# librerias para el proyecto
import pandas as pd
import numpy as np

# %% [markdown]
# EXTRAER

# %%
# Cargar el archivo CSV
df = pd.read_csv("ventas.csv")

# Ver las primeras filas
df.head()
# Out:
#         fecha    tienda  producto categoria  unidades  precio_unitario
# 0  2025-05-01  Tienda A    Camisa      Ropa         2               20
# 1  2025-05-01  Tienda B   Zapatos   Calzado         1               50
# 2  2025-05-02  Tienda A  Pantalón      Ropa         3               25
# 3  2025-05-02  Tienda C    Camisa      Ropa         2               20
# 4  2025-05-03  Tienda B  Pantalón      Ropa         1               25

# %% [markdown]
# TRANSFORMAR

# %%
# Crear una nueva columna de total por venta
df["total_venta"] = df["unidades"] * df["precio_unitario"]

# Agrupar por tienda y sumar las ventas
ventas_por_tienda = df.groupby("tienda")["total_venta"].sum().reset_index()

# Renombrar columnas
ventas_por_tienda.columns = ["Tienda", "Total Ventas"]

# Ordenar de mayor a menor
ventas_por_tienda = ventas_por_tienda.sort_values("Total Ventas", ascending=False)

# Mostrar resultados
ventas_por_tienda
# Out:
#      Tienda  Total Ventas
# 0  Tienda A           295
# 1  Tienda B           225
# 2  Tienda C           165

# %% [markdown]
# CARGAR

# %%
# Exportar el archivo Excel
ventas_por_tienda.to_excel("reporte_final.xlsx", index=False)

print("¡Reporte generado con éxito!")
# Out:
# ¡Reporte generado con éxito!
